# %% [markdown]
# # Unit 3 Exercise 4, polynomial regression
# Exercise has been downloaded and may contain alterations to the original code.
#
# Polynomial regression extends linear regression by fitting a nonlinear relationship between the independent and dependent variables using polynomial terms. It allows for more flexibility in capturing complex patterns in the data by adding polynomial features (e.g.,
#
# F2 score is a metric used to evaluate the performance of a classification model, balancing precision and recall, but giving more weight to recall. It is especially useful when the cost of false negatives is high compared to false positives. The F2 score ranges from 0 to 1, with 1 indicating perfect precision and recall.

# %% [markdown]
# 18 cars passing a certain tollboth at different time of the day (x) with different speed (y)

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

#NumPy has a method that lets us make a polynomial model
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

#specify how the line will display, we start at position 1, and end at position 22
myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# It is important to know how well the relationship between the values of the x- and y-axis is, if there are no relationship the polynomial regression can not be used to predict anything.
#
# The relationship is measured with a value called the r-squared.
#
# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451027

# %% [markdown]
# ## Predict Future Values

# %% [markdown]
# Let us try to predict the speed of a car that passes the tollbooth at around 17 P.M

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269697987

# %% [markdown]
# ![img_polynomial_prediction.png](attachment:img_polynomial_prediction.png)
